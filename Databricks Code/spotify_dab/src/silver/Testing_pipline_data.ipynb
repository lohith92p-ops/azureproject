# %%
# %sql
SELECT * FROM spotify_cata.silver.dimtrack;

# %%
df = spark.read .format("delta").load("abfss://silver@lohithazureproject.dfs.core.windows.net/DimTrack/data")

display(df)

# %%
# %sql
SELECT * FROM spotify_cata.silver.factstream;

# %%
df = spark.read \
    .option("pathGlobFilter", "*.parquet") \
    .parquet("abfss://bronze@lohithazureproject.dfs.core.windows.net/FactStream")

df.display()

# %% [markdown]
# # dimartist , dimdate , factstream , dimtrack , dimuser

# %%
# %sql

DROP TABLE spotify_cata.silver.dimuser;

# %% [markdown]
# dimartist , dimdate , factstream , dimtrack , dimuser

# %%
# %sql
DROP TABLE spotify_cata.gold.dimuser;

# %%
# %sql
SELECT * FROM spotify_cata.gold.dimtrack

# %%
# %sql
SELECT * FROM spotify_cata.gold.dimtrack
WHERE `__END_AT` IS NOT NULL

# %%
# %sql
SELECT * FROM spotify_cata.gold.dimtrack
WHERE track_id IN (5,46)
